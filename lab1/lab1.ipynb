# %%
import numpy as np

# %%
my_array = np.array([1, 2, 3, 4])
# works as it would with a standard list
len(my_array)

# %%
my_array.shape

# %%
my_array.dtype

# %%
my_array.mean()

# %%
import matplotlib.pyplot as plt

x = [1, 2]
y = [1, 5]
plt.plot(x, y)
plt.show()
